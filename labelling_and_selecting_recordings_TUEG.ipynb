# %%
import numpy as np
import pandas as pd
import logging

import glob
import re
import pickle

# %%
#reports = pd.read_csv('/home/gemeinl/tuh_eeg_complete_description.csv',  index_col=0)
#reports.to_csv('./tuh_eeg_complete_description.csv')
reports = pd.read_csv('/tuh_eeg_complete_description.csv',  index_col=0)#engine='python', encoding='utf-8', error_bad_lines=False)
#

# %%
len(reports)
# Out:
# 69582

# %%
impression = []
interpretation_idx = []
for irec in range(0,len(reports)): #69582
    text = str(reports.report[irec]).lower()
    if text.find('impression:') != -1:
        start = text.index('impression:') # 'IMPRESSION'
        if text[start:].find('clinical')!= -1:
            end = text[start:].index('clinical')
            endtext = start + end 
            impression.append(text[start:endtext])
        else:
            if text[start:].find('.\n\n')!= -1:
                end = text[start:].index('.\n\n')
                endtext = start + end 
                impression.append(text[start:endtext])
            else:
                end = text[start:].index('\n')
                endtext = start + end 
                impression.append(text[start:endtext])  
    elif text.find('impression/clinical') != -1:
        start = text.index('impression/clinical') # 'IMPRESSION'
       # if text[start:].find('CLINICAL')!= -1:
       #     end = text[start:].index('CLINICAL')
      ##      endtext = start + end 
        #impression.append(text[start:endtext])
       # else:
       
        if text[start:].find('.\n\n')!= -1:
            end = text[start:].index('.\n\n')
            endtext = start + end 
            impression.append(text[start:endtext])
        else:
            end = text[start:].index('\n')
            endtext = start + end 
            impression.append(text[start:endtext])     
    elif text.find('impression & clinical') != -1:
        start = text.index('impression & clinical') # 'IMPRESSION'
       # if text[start:].find('CLINICAL')!= -1:
       #     end = text[start:].index('CLINICAL')
      ##      endtext = start + end 
        #impression.append(text[start:endtext])
       # else:
       
        if text[start:].find('.\n\n')!= -1:
            end = text[start:].index('.\n\n')
            endtext = start + end 
            impression.append(text[start:endtext])
        else:
            end = text[start:].index('\n')
            endtext = start + end 
            impression.append(text[start:endtext])             
    elif text.find('impression') != -1:
        start = text.index('impression') # 'IMPRESSION'
        if text[start:].find('clinical')!= -1:
            end = text[start:].index('clinical')
            endtext = start + end 
            impression.append(text[start:endtext])
        else:
            if text[start:].find('.\n\n')!= -1:
                end = text[start:].index('.\n\n')
                endtext = start + end 
                impression.append(text[start:endtext])
            else:
                end = text[start:].index('\n')
                endtext = start + end 
                impression.append(text[start:endtext])           

        
    elif text.find('interpretation') != -1:
        start = text.index('interpretation') # 'IMPRESSION'
       # if text[start:].find('CLINICAL')!= -1:
       #     end = text[start:].index('CLINICAL')
      ##      endtext = start + end 
        #impression.append(text[start:endtext])
        interpretation_idx.extend([irec])
       # else:
        if text[start:].find('.\n\n')!= -1:
            end = text[start:].index('.\n\n')
            endtext = start + end 
            impression.append(text[start:endtext])
        else:
            end = text[start:].index('\n')
            endtext = start + end 
            impression.append(text[start:endtext])  
    else: impression.append('nan')      
        
print('len(impression)',len(impression)) #should be    69582
print('len(interpretation)',len(interpretation_idx)) #should be    12335
# Out:
# len(impression) 69582
# len(interpretation) 12384

# %%
impression = [w.replace(':\n', ' ') for w in impression]
#t = [w.replace('\n', '') for w in t]
#[w.replace(' \n', '') for w in t]
impression = [w.replace('.\n', '. ') for w in impression]
impression =[w.replace('\t', '') for w in impression]



reports['impression'] = impression

# %%
import re  # newlabelling
## find all recors with abnormal impression
abnormal = []

for irec in range(0,len(reports)): #69582
    text = str(reports.impression[irec])
    text = text.lower()
#     if reports.PATHOLOGICAL[irec] == False:
    regex1=re.compile(r"\babnormal")
    regex2=re.compile(r"\bno normal")
    regex3=re.compile(r"\bnot normal")
    regex4=re.compile(r"\bno abnormal")
    regex5=re.compile(r"\bnot abnormal")
    regex6=re.compile(r"\bnormal eeg")
    regex7=re.compile(r"\ba normal")
    regex8=re.compile(r"\babsence of a normal ")
    regex9=re.compile(r"\breplacement of a normal ")
    regex10=re.compile(r"\babsence of normal ")
    regex11=re.compile(r"\babnormal eeg")
    regex12=re.compile(r"\bno epileptiform abnormalities")  
    regex13=re.compile(r"\bis just outside of the range of normal")
    if (regex1.findall(text) != [] or regex2.findall(text) != [] or regex3.findall(text) != [] or regex8.findall(text) != [] or regex9.findall(text) != [] or regex10.findall(text) != [] or regex11.findall(text) != [] or regex13.findall(text) != [] ) and\
       (regex4.findall(text) == [] and regex5.findall(text) == []  and regex6.findall(text) == []  and \
         (regex7.findall(text) == [] or (regex7.findall(text) != [] and regex8.findall(text) != []) or (regex7.findall(text) != [] and regex11.findall(text) != []) or \
          (regex7.findall(text) != [] and regex9.findall(text) != []) or (regex7.findall(text) != [] and regex10.findall(text) != []) or\
         (regex7.findall(text) == [] and regex9.findall(text) == []))):
        abnormal.append(True)  #
         
    elif text.lower()== 'nan':
        abnormal.append('nan')    
    else: abnormal.append(False)    
    del regex1, regex2, regex3, regex4,regex5,regex6,regex7, regex8, regex9,regex10,regex11,regex12, regex13,text    
print(len(abnormal)) # should be 69582

reports['pathological'] = abnormal #69582

## find all recors with normal impression
normal = []
for irec in range(0,len(reports)):
   # text = str(reports.IMPRESSION[irec])
    #text = text.lower()
    if reports.pathological[irec] == False:
        text = str(reports.impression[irec])
        text = text.lower()
        regex1=re.compile(r"\bnormal")
        regex2=re.compile(r"\bno abnormal")
        regex3=re.compile(r"\bnot abnormal")
        regex4=re.compile(r"\bno normal")
        regex5=re.compile(r"\bnot normal")
        regex6=re.compile(r"\babnormal eeg")
        if (regex1.findall(text) != [] or regex2.findall(text) != [] or regex3.findall(text) != []) and (regex4.findall(text) == [] and regex5.findall(text) == [] and regex6.findall(text) == []):
            normal.append(True)
        else:
            normal.append('no label')
        del regex1, regex2, regex3, regex4, regex5,regex6, text    
    if reports.pathological[irec] == 'nan':
        normal.append('nan')    
    if reports.pathological[irec] == True:   
        normal.append(False)
    #del text    
print(len(normal)) # should be 69582

reports['normal'] = list(normal)
# Out:
# 69582
# 69582

# %%
occurrences = abnormal.count(True)
normal_occ = normal.count(True)
nokey = normal.count('no label')
nan = abnormal.count('nan')
print('Num records: ', len(abnormal)), print('abnormal :', occurrences) , print('normal :', normal_occ), print('no keyword found :', nokey), print('no Impression or Report :', nan)

# Num records:  69582
# abnormal : 38399
# normal : 13669
# no keyword found : 14565
# no Impression or Report : 2949
#
# Out:
# Num records:  69582
# abnormal : 38399
# normal : 13669
# no keyword found : 14565
# no Impression or Report : 2949
# (None, None, None, None, None)

# %%
38339+13669 # num of labelled recordings
# Out:
# 52008

# %%
reports.to_pickle("reports_TUEG_labelled.pkl")

# %%
reports
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# ...                                                  ...     ...   ...    ...
# 69577  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69578  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69579  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69580  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69581  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        3       13        1        1        le  250.0      61000   46      F
# 1        3       13        1        2        le  250.0      42000   46      F
# 2        3       13        1        3        le  250.0     197250   46      F
# 3        4       14        1        1        le  250.0     306500   57      M
# 4       19        5        1        0        le  250.0      33750   49      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 69577    3    14898        1        0        ar  256.0      18688   26      F
# 69578    3    14898        1        1        ar  256.0       8448   26      F
# 69579    3    14898        1        2        ar  256.0     126976   26      F
# 69580    3    14898        1        3        ar  256.0     173056   26      F
# 69581    3    14898        1        4        ar  256.0     107520   26      F
#
#                                                   report  \
# 0      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 1      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 2      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 3      CLINICAL HISTORY: This is a 57-year-old, right...
# 4      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# ...                                                  ...
# 69577  HISTORY:\n\n25 y.o. female with a history of f...
# 69578  HISTORY:\n\n25 y.o. female with a history of f...
# 69579  HISTORY:\n\n25 y.o. female with a history of f...
# 69580  HISTORY:\n\n25 y.o. female with a history of f...
# 69581  HISTORY:\n\n25 y.o. female with a history of f...
#
#                                               impression pathological normal
# 0      impression:  technically limited but normal  e...        False   True
# 1      impression:  technically limited but normal  e...        False   True
# 2      impression:  technically limited but normal  e...        False   True
# 3      impression: probably abnormal eeg due to right...         True  False
# 4      impression: abnormal eeg due to 1. right tempo...         True  False
# ...                                                  ...          ...    ...
# 69577  impression \n\nthis is a normal awake and drow...        False   True
# 69578  impression \n\nthis is a normal awake and drow...        False   True
# 69579  impression \n\nthis is a normal awake and drow...        False   True
# 69580  impression \n\nthis is a normal awake and drow...        False   True
# 69581  impression \n\nthis is a normal awake and drow...        False   True
#
# [69582 rows x 17 columns]

# %%
### selected chans and duration
label_all_tuh =  reports #pd.read_pickle("./reports_labelled.pkl")

# %%
#label_all_tuh[label_all_tuh['subject']==13749]['report']
# Out:
# 33421    HISTORY:\n\n30 y.o. with a history polysubstan...
# Name: report, dtype: object

# %%
artifact_set = pd.read_csv("./artifact_corpus_labels.csv") 
#artifact_set

artifact = artifact_set.rename(columns={"seesion": "session"})
eval_set= label_all_tuh
all_index = []
for iAB in range(len(artifact)):
    index = list(eval_set.loc[(eval_set['subject']== artifact['subject'][iAB])& (eval_set['year']== artifact['year'][iAB]) & (eval_set['month']== artifact['month'][iAB]) & (eval_set['day']== artifact['day'][iAB]) &  (eval_set['session']== artifact['session'][iAB]) ].index)
    all_index.extend(index)
    del index
len(all_index)   
eval_wo_arti= eval_set.drop(all_index)

# %%
len(eval_wo_arti) # 38674 recordings after excluding artifact corpus
# Out:
# 68805

# %%
tuab = pd.read_pickle("/home/kiessnek/TUHEEG_decoding/labels/TUHABnormaldescription.pkl")

# %%
# TUHAB = tuab#datasetAB.description #artifact.rename(columns={"seesion": "session"})
# eval2= eval_wo_arti

# all_index = []
# for iAB in range(len(TUHAB)):
#     index = list(eval2.loc[(eval2['year']== TUHAB['year'][iAB])& (eval2['subject']== TUHAB['subject'][iAB]) & (eval2['segment']== TUHAB['segment'][iAB]) & (eval2['session']== TUHAB['session'][iAB]) & (eval2['day']== TUHAB['day'][iAB])].index)
#     all_index.extend(index)
#     del index

# %%
TUHAB = tuab# delete all subjects from TUHAB
eval2= eval_wo_arti

all_index = []
for iAB in range(len(TUHAB)):
    index = list(eval2.loc[(eval2['subject']== TUHAB['subject'][iAB])].index)
    all_index.extend(index)
    del index



eval_final= eval2.drop(all_index)

eval_final
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# ...                                                  ...     ...   ...    ...
# 69577  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69578  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69579  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69580  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69581  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        3       13        1        1        le  250.0      61000   46      F
# 1        3       13        1        2        le  250.0      42000   46      F
# 2        3       13        1        3        le  250.0     197250   46      F
# 3        4       14        1        1        le  250.0     306500   57      M
# 4       19        5        1        0        le  250.0      33750   49      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 69577    3    14898        1        0        ar  256.0      18688   26      F
# 69578    3    14898        1        1        ar  256.0       8448   26      F
# 69579    3    14898        1        2        ar  256.0     126976   26      F
# 69580    3    14898        1        3        ar  256.0     173056   26      F
# 69581    3    14898        1        4        ar  256.0     107520   26      F
#
#                                                   report  \
# 0      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 1      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 2      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 3      CLINICAL HISTORY: This is a 57-year-old, right...
# 4      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# ...                                                  ...
# 69577  HISTORY:\n\n25 y.o. female with a history of f...
# 69578  HISTORY:\n\n25 y.o. female with a history of f...
# 69579  HISTORY:\n\n25 y.o. female with a history of f...
# 69580  HISTORY:\n\n25 y.o. female with a history of f...
# 69581  HISTORY:\n\n25 y.o. female with a history of f...
#
#                                               impression pathological normal
# 0      impression:  technically limited but normal  e...        False   True
# 1      impression:  technically limited but normal  e...        False   True
# 2      impression:  technically limited but normal  e...        False   True
# 3      impression: probably abnormal eeg due to right...         True  False
# 4      impression: abnormal eeg due to 1. right tempo...         True  False
# ...                                                  ...          ...    ...
# 69577  impression \n\nthis is a normal awake and drow...        False   True
# 69578  impression \n\nthis is a normal awake and drow...        False   True
# 69579  impression \n\nthis is a normal awake and drow...        False   True
# 69580  impression \n\nthis is a normal awake and drow...        False   True
# 69581  impression \n\nthis is a normal awake and drow...        False   True
#
# [51642 rows x 17 columns]

# %%
report_final= eval_final
new_labelsa = report_final[(report_final["pathological"] == True)]
new_labelsb = report_final[(report_final["pathological"] == False) & (report_final["normal"] == True) ]

new_labels = pd.concat([new_labelsa, new_labelsb])

len(new_labels)
# Out:
# 38674

# %%
report_final[(report_final["pathological"] == False) & (report_final["normal"] == 'no label') ].iloc[20:40]
# Out:
#                                                   path version  year  month  \
# 179  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      1
# 180  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      1
# 273  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 286  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 287  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 288  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 289  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 290  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 291  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 292  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 293  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 294  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 373  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 374  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 375  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 376  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 377  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 378  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 379  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
# 380  /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      2
#
#      day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 179   22      392        2       13        le  250.0       1500   59      M
# 180   22      392        2       14        le  250.0    1330500   59      M
# 273    9      229        1        0        le  250.0     304000   65      F
# 286   11      224        2        0        le  250.0      77000   74      M
# 287   11      224        2        1        le  250.0       5000   74      M
# 288   11      224        2        7        le  250.0     129250   74      M
# 289   11      224        2        8        le  250.0       3750   74      M
# 290   11      224        2        9        le  250.0      72250   74      M
# 291   11      224        2       10        le  250.0       8250   74      M
# 292   11      224        2       12        le  250.0     468500   74      M
# 293   11      224        2       14        le  250.0    1169000   74      M
# 294   11      224        2       15        le  250.0     106500   74      M
# 373   26      392        3        0        le  250.0      84250   59      M
# 374   26      392        3        1        le  250.0      40750   63      M
# 375   26      392        3        2        le  250.0      52250   63      M
# 376   26      392        3        3        le  250.0      25750   59      M
# 377   26      392        3        4        le  250.0       8750   59      M
# 378   26      392        3        6        le  250.0      27000   59      M
# 379   26      392        3        7        le  250.0       3750   59      M
# 380   26      392        3        8        le  250.0     122500   59      M
#
#                                                 report  \
# 179  CLINICAL HISTORY: This is a 58-year-old, right...
# 180  CLINICAL HISTORY: This is a 58-year-old, right...
# 273  CLINICAL HISTORY: This is a 64-year-old woman ...
# 286  CLINICAL HISTORY: This is a 73-year-old, right...
# 287  CLINICAL HISTORY: This is a 73-year-old, right...
# 288  CLINICAL HISTORY: This is a 73-year-old, right...
# 289  CLINICAL HISTORY: This is a 73-year-old, right...
# 290  CLINICAL HISTORY: This is a 73-year-old, right...
# 291  CLINICAL HISTORY: This is a 73-year-old, right...
# 292  CLINICAL HISTORY: This is a 73-year-old, right...
# 293  CLINICAL HISTORY: This is a 73-year-old, right...
# 294  CLINICAL HISTORY: This is a 73-year-old, right...
# 373  CLINICAL HISTORY: This is a 58-year-old, right...
# 374  CLINICAL HISTORY: This is a 58-year-old, right...
# 375  CLINICAL HISTORY: This is a 58-year-old, right...
# 376  CLINICAL HISTORY: This is a 58-year-old, right...
# 377  CLINICAL HISTORY: This is a 58-year-old, right...
# 378  CLINICAL HISTORY: This is a 58-year-old, right...
# 379  CLINICAL HISTORY: This is a 58-year-old, right...
# 380  CLINICAL HISTORY: This is a 58-year-old, right...
#
#                                             impression pathological    normal
# 179  impression/clinical correlation: eeg monitorin...        False  no label
# 180  impression/clinical correlation: eeg monitorin...        False  no label
# 273  impression/clinical correlation: this eeg was ...        False  no label
# 286  impression/clinical correlation: eeg monitorin...        False  no label
# 287  impression/clinical correlation: eeg monitorin...        False  no label
# 288  impression/clinical correlation: eeg monitorin...        False  no label
# 289  impression/clinical correlation: eeg monitorin...        False  no label
# 290  impression/clinical correlation: eeg monitorin...        False  no label
# 291  impression/clinical correlation: eeg monitorin...        False  no label
# 292  impression/clinical correlation: eeg monitorin...        False  no label
# 293  impression/clinical correlation: eeg monitorin...        False  no label
# 294  impression/clinical correlation: eeg monitorin...        False  no label
# 373  impression/clinical correlation: eeg monitorin...        False  no label
# 374  impression/clinical correlation: eeg monitorin...        False  no label
# 375  impression/clinical correlation: eeg monitorin...        False  no label
# 376  impression/clinical correlation: eeg monitorin...        False  no label
# 377  impression/clinical correlation: eeg monitorin...        False  no label
# 378  impression/clinical correlation: eeg monitorin...        False  no label
# 379  impression/clinical correlation: eeg monitorin...        False  no label
# 380  impression/clinical correlation: eeg monitorin...        False  no label

# %%
report_final#['report'].iloc[69330:]
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# ...                                                  ...     ...   ...    ...
# 69577  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69578  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69579  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69580  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 69581  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        3       13        1        1        le  250.0      61000   46      F
# 1        3       13        1        2        le  250.0      42000   46      F
# 2        3       13        1        3        le  250.0     197250   46      F
# 3        4       14        1        1        le  250.0     306500   57      M
# 4       19        5        1        0        le  250.0      33750   49      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 69577    3    14898        1        0        ar  256.0      18688   26      F
# 69578    3    14898        1        1        ar  256.0       8448   26      F
# 69579    3    14898        1        2        ar  256.0     126976   26      F
# 69580    3    14898        1        3        ar  256.0     173056   26      F
# 69581    3    14898        1        4        ar  256.0     107520   26      F
#
#                                                   report  \
# 0      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 1      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 2      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 3      CLINICAL HISTORY: This is a 57-year-old, right...
# 4      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# ...                                                  ...
# 69577  HISTORY:\n\n25 y.o. female with a history of f...
# 69578  HISTORY:\n\n25 y.o. female with a history of f...
# 69579  HISTORY:\n\n25 y.o. female with a history of f...
# 69580  HISTORY:\n\n25 y.o. female with a history of f...
# 69581  HISTORY:\n\n25 y.o. female with a history of f...
#
#                                               impression pathological normal
# 0      impression:  technically limited but normal  e...        False   True
# 1      impression:  technically limited but normal  e...        False   True
# 2      impression:  technically limited but normal  e...        False   True
# 3      impression: probably abnormal eeg due to right...         True  False
# 4      impression: abnormal eeg due to 1. right tempo...         True  False
# ...                                                  ...          ...    ...
# 69577  impression \n\nthis is a normal awake and drow...        False   True
# 69578  impression \n\nthis is a normal awake and drow...        False   True
# 69579  impression \n\nthis is a normal awake and drow...        False   True
# 69580  impression \n\nthis is a normal awake and drow...        False   True
# 69581  impression \n\nthis is a normal awake and drow...        False   True
#
# [51642 rows x 17 columns]

# %%
df_sorted=new_labels.sort_values(by=['year', 'month', 'day', 'subject', 'session', 'segment'])
# ids_sorted = list(df_sorted.index)
# train_complete = train_combined.split(ids_sorted)['0']

df_sorted['pathological']= df_sorted['pathological'].astype(int)

#df_sorted= df_sorted.drop(columns=['normal'])
df_sorted= df_sorted.reset_index(drop=True)

# %%
df_sorted.to_pickle('./TUEG_reports_labelled_and_selected.pkl')

# %%
df_sorted
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# ...                                                  ...     ...   ...    ...
# 38669  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38670  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38671  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38672  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38673  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        3       13        1        1        le  250.0      61000   46      F
# 1        3       13        1        2        le  250.0      42000   46      F
# 2        3       13        1        3        le  250.0     197250   46      F
# 3        4       14        1        1        le  250.0     306500   57      M
# 4       19        5        1        0        le  250.0      33750   49      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 38669    3    14898        1        0        ar  256.0      18688   26      F
# 38670    3    14898        1        1        ar  256.0       8448   26      F
# 38671    3    14898        1        2        ar  256.0     126976   26      F
# 38672    3    14898        1        3        ar  256.0     173056   26      F
# 38673    3    14898        1        4        ar  256.0     107520   26      F
#
#                                                   report  \
# 0      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 1      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 2      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 3      CLINICAL HISTORY: This is a 57-year-old, right...
# 4      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# ...                                                  ...
# 38669  HISTORY:\n\n25 y.o. female with a history of f...
# 38670  HISTORY:\n\n25 y.o. female with a history of f...
# 38671  HISTORY:\n\n25 y.o. female with a history of f...
# 38672  HISTORY:\n\n25 y.o. female with a history of f...
# 38673  HISTORY:\n\n25 y.o. female with a history of f...
#
#                                               impression  pathological
# 0      impression:  technically limited but normal  e...             0
# 1      impression:  technically limited but normal  e...             0
# 2      impression:  technically limited but normal  e...             0
# 3      impression: probably abnormal eeg due to right...             1
# 4      impression: abnormal eeg due to 1. right tempo...             1
# ...                                                  ...           ...
# 38669  impression \n\nthis is a normal awake and drow...             0
# 38670  impression \n\nthis is a normal awake and drow...             0
# 38671  impression \n\nthis is a normal awake and drow...             0
# 38672  impression \n\nthis is a normal awake and drow...             0
# 38673  impression \n\nthis is a normal awake and drow...             0
#
# [38674 rows x 16 columns]

# %%
## select data based on duration and channels

# %%
import time
import os
import mne
mne.set_log_level('ERROR')

from warnings import filterwarnings
filterwarnings('ignore')


from IPython.utils import io

import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


import torch
from torch.nn.functional import relu

from braindecode import EEGClassifier
from braindecode.training.losses import CroppedLoss
from braindecode.models import Deep4Net,ShallowFBCSPNet
from braindecode.util import set_random_seeds
from braindecode.models.util import to_dense_prediction_model, get_output_shape

from braindecode.datautil.windowers import create_fixed_length_windows
from braindecode.datautil.serialization import  load_concat_dataset

from braindecode.datasets import BaseConcatDataset


from functools import partial 
from skorch.callbacks import LRScheduler, EarlyStopping,Checkpoint, EpochScoring
from skorch.helper import predefined_split


    
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error

import sys
sys.path.insert(0, '/home/kiessnek/TUHEEG_decoding/')
from ImbalancedDatasetSampler import ImbalancedDatasetSampler

from itertools import product

import GPUtil


#######################
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm


from braindecode.datasets.tuh import TUHAbnormal, TUH
from braindecode.datasets.base import BaseDataset,BaseConcatDataset    
from IPython.utils import io


import mne
import re
import os
import glob

import pandas as pd
import mne

def get_TUH_labeled(path_TUH, label_file, recording_ids=None):

        #from braindecode.datasets.tuh import TUH
       # add_physician_reports = True
        #self.label_file= label_file
        wanted_reports, paths = _load_labels(label_file) #,label_abnormal, label_normal

        all_datasets = []
        label_list =[]

        if recording_ids is None:
            recording_ids = len(paths)
           
        recording_reports = wanted_reports[:recording_ids]
        
        label_list = recording_reports['pathological'] #['PATHOLOGICAL']
        
       # recording_reports
       # del recording_reports['IMPRESSION'] 
        #del recording_reports['PATHOLOGICAL'] 
       # del recording_reports['Normal'] 
        
        TUH_all_datasets = _load_TUH_labeled(reports_to_load=recording_reports, target_name=None, preload=False,
                         add_physician_reports=True)
        
             
        # adapt dataframe 
        # add dataset and pathologcial column so df. columns are identical between TUHEEG and TUHAbnormal

        all_datasets=BaseConcatDataset(TUH_all_datasets)
        target = label_list
        

             
        for d, y in zip(all_datasets.datasets, target):
            d.description['pathological'] = y
            d.target_name = 'pathological'
            d.target = d.description[d.target_name]
        all_datasets.set_description(pd.DataFrame([d.description for d in all_datasets.datasets]), overwrite=True)

       
        ds_name = ['TUHEEG'] * len(all_datasets.datasets)
        for ds, ys in zip(all_datasets.datasets, ds_name):
            ds.description['dataset'] = ys
            ds.target_name = 'dataset'
            ds.target = ds.description[d.target_name]
        all_datasets.set_description(pd.DataFrame([d.description for d in all_datasets.datasets]), overwrite=True)
        #all_datasets.set_description = (pd.DataFrame([d.description for d in all_datasets.datasets]),overwrite=True)

        all_datasets.description['dataset'] = 'TUHEEG'
        

        
        return all_datasets, label_list
        print(len(all_datasets), len(label_list))    

def _load_TUH_labeled(reports_to_load, target_name=None, preload=False,
                     add_physician_reports=True):
    base_datasets = []
    #descriptions  = reports_to_load
    for file_path_i, file_path in reports_to_load['path'].iteritems():
        # parse age and gender information from EDF header
        age,  gender = _parse_age_and_gender_from_edf_header(file_path) #test_report['age'][file_path_i]#
        #gender = test_report['gender'][file_path_i]
        raw = mne.io.read_raw_edf(file_path, preload=preload)
        # read info relevant for preprocessing from raw without loading it
        sfreq = raw.info['sfreq']
        n_samples = raw.n_times
        d = {
            'sfreq': float(sfreq),
            'n_samples': int(n_samples),
            'age': int(age),
            'gender': gender,
            }
        if add_physician_reports:
            physician_report = _read_physician_report(file_path)
            d['report'] = physician_report
        additional_description = pd.Series(d)
        #description = pd.concat(
        #   [reports_to_load, additional_description]) #descriptions.pop(file_path_i)
        description =reports_to_load.iloc[file_path_i]
        base_dataset = BaseDataset(raw, description,
                                   target_name=target_name)
        base_datasets.append(base_dataset)


    return base_datasets   
            
def _load_labels(filepath):


    reports = pd.read_pickle(filepath)
    
    wanted_reports = reports#[(reports['PATHOLOGICAL'] == True) | (reports['Normal'] == True)]# get normal and abnormal recordings
   # wanted_reports = reports[(reports['PATHOLOGICAL'] == True) | (reports['Normal'] == True)]# get normal and abnormal recordings

    paths = wanted_reports['path'].reset_index(drop=True)
    
    wanted_reports = wanted_reports.reset_index(drop=True)

    #label_abnormal = wanted_reports['PATHOLOGICAL'].reset_index(drop=True)
    #label_normal = wanted_reports['Normal'].reset_index(drop=True)

    return wanted_reports, paths#, label_abnormal, label_normal

def _parse_age_and_gender_from_edf_header(file_path):
    header = _read_edf_header(file_path)
    # bytes 8 to 88 contain ascii local patient identification
    # see https://www.teuniz.net/edfbrowser/edf%20format%20description.html
    patient_id = header[8:].decode("ascii")
    age = -1
    found_age = re.findall(r"Age:(\d+)", patient_id)
    if len(found_age) == 1:
        age = int(found_age[0])
    gender = "X"
    found_gender = re.findall(r"\s([F|M])\s", patient_id)
    if len(found_gender) == 1:
        gender = found_gender[0]
    return age, gender    

def _read_edf_header(file_path):
    f = open(file_path, "rb")
    header = f.read(88)
    f.close()
    return header

def _read_physician_report(file_path):
    directory = os.path.dirname(file_path)
    txt_file = glob.glob(os.path.join(directory, '**/*.txt'), recursive=True)
    # check that there is at most one txt file in the same directory
    assert len(txt_file) in [0, 1]
    report = ''
    if txt_file:
        txt_file = txt_file[0]
        # somewhere in the corpus, encoding apparently changed
        # first try to read as utf-8, if it does not work use latin-1
        try:
            with open(txt_file, 'r', encoding='utf-8') as f:
                report = f.read()
        except UnicodeDecodeError:
            with open(txt_file, 'r', encoding='latin-1') as f:
                report = f.read()
    return report

    

from tqdm.autonotebook import tqdm

# %%
import time
#from combineTUHdatasets import *
print('load data ' )
start_load = time.time()
recording_ids=None
with io.capture_output() as captured:
    tuheeg, TUH_label_list = get_TUH_labeled(path_TUH='/data/datasets/TUH/EEG/tuh_eeg/', 
                                                                     label_file= '/home/kiessnek/TUHEEG_decoding/preprocess and save data, eliminate TUHAb recordings/labelling_TUH/TUEG_reports_labelled_and_selected.pkl', 
                                                                     recording_ids=None) #CombineTUHDatasets.
end_load= time.time()
print(end_load -start_load)
# Out:
# load data
# 1233.7344496250153

# %%
tuheeg.description
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# ...                                                  ...     ...   ...    ...
# 38669  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38670  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38671  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38672  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 38673  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        3       13        1        1        le  250.0      61000   46      F
# 1        3       13        1        2        le  250.0      42000   46      F
# 2        3       13        1        3        le  250.0     197250   46      F
# 3        4       14        1        1        le  250.0     306500   57      M
# 4       19        5        1        0        le  250.0      33750   49      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 38669    3    14898        1        0        ar  256.0      18688   26      F
# 38670    3    14898        1        1        ar  256.0       8448   26      F
# 38671    3    14898        1        2        ar  256.0     126976   26      F
# 38672    3    14898        1        3        ar  256.0     173056   26      F
# 38673    3    14898        1        4        ar  256.0     107520   26      F
#
#                                                   report  \
# 0      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 1      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 2      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 3      CLINICAL HISTORY: This is a 57-year-old, right...
# 4      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# ...                                                  ...
# 38669  HISTORY:\n\n25 y.o. female with a history of f...
# 38670  HISTORY:\n\n25 y.o. female with a history of f...
# 38671  HISTORY:\n\n25 y.o. female with a history of f...
# 38672  HISTORY:\n\n25 y.o. female with a history of f...
# 38673  HISTORY:\n\n25 y.o. female with a history of f...
#
#                                               impression  pathological dataset
# 0      impression:  technically limited but normal  e...             0  TUHEEG
# 1      impression:  technically limited but normal  e...             0  TUHEEG
# 2      impression:  technically limited but normal  e...             0  TUHEEG
# 3      impression: probably abnormal eeg due to right...             1  TUHEEG
# 4      impression: abnormal eeg due to 1. right tempo...             1  TUHEEG
# ...                                                  ...           ...     ...
# 38669  impression \n\nthis is a normal awake and drow...             0  TUHEEG
# 38670  impression \n\nthis is a normal awake and drow...             0  TUHEEG
# 38671  impression \n\nthis is a normal awake and drow...             0  TUHEEG
# 38672  impression \n\nthis is a normal awake and drow...             0  TUHEEG
# 38673  impression \n\nthis is a normal awake and drow...             0  TUHEEG
#
# [38674 rows x 17 columns]

# %%
tuh=tuheeg

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import mne

from braindecode.datasets import TUH
from braindecode.datautil.preprocess import preprocess, Preprocessor
from braindecode.datautil.windowers import create_fixed_length_windows
from braindecode.datautil.serialization import (
    save_concat_dataset, load_concat_dataset)

mne.set_log_level('ERROR')  # avoid messages everytime a window is extracted


def select_by_duration(ds, tmin=0, tmax=None):
    # determine length of the recordings and select based on tmin and tmax
    duration = ds.description.n_samples / ds.description.sfreq
    duration = duration[duration >= tmin]
    if tmax is None:
        tmax = np.inf
    duration = duration[duration <= tmax]
    split_ids = list(duration.index)
    splits = ds.split(split_ids)
    split = splits['0']
    return split


tmin = 15 * 60
tmax = None #n_max_minutes
tuh = select_by_duration(tuh, tmin, tmax)

# %%
short_ch_names = sorted([
    'A1', 'A2',
    'FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2',
    'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'FZ', 'CZ', 'PZ'])
ar_ch_names = sorted([
    'EEG A1-REF', 'EEG A2-REF',
    'EEG FP1-REF', 'EEG FP2-REF', 'EEG F3-REF', 'EEG F4-REF', 'EEG C3-REF',
    'EEG C4-REF', 'EEG P3-REF', 'EEG P4-REF', 'EEG O1-REF', 'EEG O2-REF',
    'EEG F7-REF', 'EEG F8-REF', 'EEG T3-REF', 'EEG T4-REF', 'EEG T5-REF',
    'EEG T6-REF', 'EEG FZ-REF', 'EEG CZ-REF', 'EEG PZ-REF'])
le_ch_names = sorted([
    'EEG A1-LE', 'EEG A2-LE',
    'EEG FP1-LE', 'EEG FP2-LE', 'EEG F3-LE', 'EEG F4-LE', 'EEG C3-LE',
    'EEG C4-LE', 'EEG P3-LE', 'EEG P4-LE', 'EEG O1-LE', 'EEG O2-LE',
    'EEG F7-LE', 'EEG F8-LE', 'EEG T3-LE', 'EEG T4-LE', 'EEG T5-LE',
    'EEG T6-LE', 'EEG FZ-LE', 'EEG CZ-LE', 'EEG PZ-LE'])
assert len(short_ch_names) == len(ar_ch_names) == len(le_ch_names)
ar_ch_mapping = {ch_name: short_ch_name for ch_name, short_ch_name in zip(
    ar_ch_names, short_ch_names)}
le_ch_mapping = {ch_name: short_ch_name for ch_name, short_ch_name in zip(
    le_ch_names, short_ch_names)}
ch_mapping = {'ar': ar_ch_mapping, 'le': le_ch_mapping}


def select_by_channels(ds, ch_mapping):
    split_ids = []
    for i, d in enumerate(ds.datasets):
        seta = set(ch_mapping[d.description.reference].keys())
        setb = set(d.raw.ch_names)
        if seta.issubset(setb):
            split_ids.append(i)
    return ds.split(split_ids)['0']


tuh = select_by_channels(tuh, ch_mapping)

# %%
tuh.description
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     10
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/01_t...  v1.1.0  2002     10
# ...                                                  ...     ...   ...    ...
# 20426  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 20427  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 20428  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 20429  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 20430  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        3       13        1        3        le  250.0     197250   46      F
# 1        4       14        1        1        le  250.0     306500   57      M
# 2       19        5        1        1        le  250.0     357000   49      M
# 3       21        6        1        2        le  250.0     354000   31      F
# 4       21        6        2        3        ar  400.0     248000   33      F
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 20426    5    13738        6       11        ar  256.0     168448   65      M
# 20427    8    11124        3        1        ar  256.0     383488   26      M
# 20428   15    11954        3        1        ar  256.0    9140992   54      F
# 20429   15    11954        3        2        ar  256.0    1812480   54      F
# 20430    3    14898        1        3        ar  256.0     173056   26      F
#
#                                                   report  \
# 0      \nCLINICAL HISTORY: 46-year-old tight handed f...
# 1      CLINICAL HISTORY: This is a 57-year-old, right...
# 2      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 3      \n\n\n\n\n\n\n\n\nCLINICAL  HISTORY:  This  is...
# 4      CLINICAL  HISTORY:  This  is a 33-year-old wom...
# ...                                                  ...
# 20426  HISTORY:\n\nThis is a 64 y.o. right handed mal...
# 20427  HISTORY:\n\n25 y.o. male with a history of idi...
# 20428  HISTORY:\n\n53 y.o. female with a history of m...
# 20429  HISTORY:\n\n53 y.o. female with a history of m...
# 20430  HISTORY:\n\n25 y.o. female with a history of f...
#
#                                               impression  pathological dataset
# 0      impression:  technically limited but normal  e...             0  TUHEEG
# 1      impression: probably abnormal eeg due to right...             1  TUHEEG
# 2      impression: abnormal eeg due to 1. right tempo...             1  TUHEEG
# 3      impression: abnormal long-term video eeg monit...             1  TUHEEG
# 4      impression: abnormal long-term video eeg monit...             1  TUHEEG
# ...                                                  ...           ...     ...
# 20426  impression & clinical correlation \n\nthis is ...             1  TUHEEG
# 20427  impression \nthis is an abnormal awake only  r...             1  TUHEEG
# 20428  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
# 20429  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
# 20430  impression \n\nthis is a normal awake and drow...             0  TUHEEG
#
# [20431 rows x 17 columns]

# %%
tuh.description.to_pickle("./selected_labelled_reports_10min.pkl")

# %%
len(tuh.description[tuh.description['pathological']==1]),len(tuh.description[tuh.description['pathological']==0])
# Out:
# (20320, 6820)

# %%
15 min (10838, 4462) 15300  patho normal total
10 min (15131, 5300) 20431
5 min (20320, 6820) 27140
2 min (21772, 7290, 29062)

# %%
15131+5300
# Out:
# 20431

# %%
4462/15300
# Out:
# 0.29163398692810455

# %%
tuh_15 = tuh.description

# %%
tuh_15.drop_duplicates(subset=['year', 'month', 'day', 'subject', 'session', 'segment'])
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     10
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# ...                                                  ...     ...   ...    ...
# 15295  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      1
# 15296  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15297  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15298  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15299  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
#
#        day  subject  session  segment reference   sfreq  n_samples  age  \
# 0        4       14        1        1        le   250.0     306500   57
# 1       19        5        1        1        le   250.0     357000   49
# 2       21        6        1        2        le   250.0     354000   31
# 3       23       11        1        0        le   250.0     304000   31
# 4       24        7        1        0        le   250.0     300000   40
# ...    ...      ...      ...      ...       ...     ...        ...  ...
# 15295   23    14101        1        0        ar  1000.0    1420000   75
# 15296    3    13738        1        0        ar   256.0     340992   65
# 15297    8    11124        3        1        ar   256.0     383488   26
# 15298   15    11954        3        1        ar   256.0    9140992   54
# 15299   15    11954        3        2        ar   256.0    1812480   54
#
#       gender                                             report  \
# 0          M  CLINICAL HISTORY: This is a 57-year-old, right...
# 1          M  \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 2          F  \n\n\n\n\n\n\n\n\nCLINICAL  HISTORY:  This  is...
# 3          F  CLINICAL HISTORY: This is a 31-year-old woman ...
# 4          M  CLINICAL HISTORY: This is a 42-year-old man wi...
# ...      ...                                                ...
# 15295      F  DATE OF STUDY: 01/23/17
# RECORDING ENVIRONMENT:...
# 15296      M  HISTORY:\n\n64 y.o. male with a history of gun...
# 15297      M  HISTORY:\n\n25 y.o. male with a history of idi...
# 15298      F  HISTORY:\n\n53 y.o. female with a history of m...
# 15299      F  HISTORY:\n\n53 y.o. female with a history of m...
#
#                                               impression  pathological dataset
# 0      impression: probably abnormal eeg due to right...             1  TUHEEG
# 1      impression: abnormal eeg due to 1. right tempo...             1  TUHEEG
# 2      impression: abnormal long-term video eeg monit...             1  TUHEEG
# 3      impression: normal eeg in wakefulness through ...             0  TUHEEG
# 4      impression: abnormal eeg due to focal slowing ...             1  TUHEEG
# ...                                                  ...           ...     ...
# 15295  impression:
# this is an abnormal bedside eeg du...             1  TUHEEG
# 15296  impression \n\n\nthis is an abnormal awake and...             1  TUHEEG
# 15297  impression \nthis is an abnormal awake only  r...             1  TUHEEG
# 15298  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
# 15299  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
#
# [15300 rows x 17 columns]

# %%
tuh.description.to_pickle("./selected_labelled_reports_15min.pkl")

# %%
tuh.description['report'].iloc[26756]

# %%
tuh_selected =tuh.description

# %%
tuh_selected= pd.read_pickle("./selected_labelled_reports_15min.pkl")

# %%
len(tuh_selected[tuh_selected['pathological']==1]),len(tuh_selected[tuh_selected['pathological']==0]), len(tuh_selected)
# Out:
# (10838, 4462, 15300)

# %%
4462/15300
# Out:
# 0.29163398692810455

# %%
tuh_selected
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     10
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# ...                                                  ...     ...   ...    ...
# 15295  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      1
# 15296  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15297  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15298  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15299  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
#
#        day  subject  session  segment reference   sfreq  n_samples  age  \
# 0        4       14        1        1        le   250.0     306500   57
# 1       19        5        1        1        le   250.0     357000   49
# 2       21        6        1        2        le   250.0     354000   31
# 3       23       11        1        0        le   250.0     304000   31
# 4       24        7        1        0        le   250.0     300000   40
# ...    ...      ...      ...      ...       ...     ...        ...  ...
# 15295   23    14101        1        0        ar  1000.0    1420000   75
# 15296    3    13738        1        0        ar   256.0     340992   65
# 15297    8    11124        3        1        ar   256.0     383488   26
# 15298   15    11954        3        1        ar   256.0    9140992   54
# 15299   15    11954        3        2        ar   256.0    1812480   54
#
#       gender                                             report  \
# 0          M  CLINICAL HISTORY: This is a 57-year-old, right...
# 1          M  \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 2          F  \n\n\n\n\n\n\n\n\nCLINICAL  HISTORY:  This  is...
# 3          F  CLINICAL HISTORY: This is a 31-year-old woman ...
# 4          M  CLINICAL HISTORY: This is a 42-year-old man wi...
# ...      ...                                                ...
# 15295      F  DATE OF STUDY: 01/23/17
# RECORDING ENVIRONMENT:...
# 15296      M  HISTORY:\n\n64 y.o. male with a history of gun...
# 15297      M  HISTORY:\n\n25 y.o. male with a history of idi...
# 15298      F  HISTORY:\n\n53 y.o. female with a history of m...
# 15299      F  HISTORY:\n\n53 y.o. female with a history of m...
#
#                                               impression  pathological dataset
# 0      impression: probably abnormal eeg due to right...             1  TUHEEG
# 1      impression: abnormal eeg due to 1. right tempo...             1  TUHEEG
# 2      impression: abnormal long-term video eeg monit...             1  TUHEEG
# 3      impression: normal eeg in wakefulness through ...             0  TUHEEG
# 4      impression: abnormal eeg due to focal slowing ...             1  TUHEEG
# ...                                                  ...           ...     ...
# 15295  impression:
# this is an abnormal bedside eeg du...             1  TUHEEG
# 15296  impression \n\n\nthis is an abnormal awake and...             1  TUHEEG
# 15297  impression \nthis is an abnormal awake only  r...             1  TUHEEG
# 15298  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
# 15299  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
#
# [15300 rows x 17 columns]

# %%
len(eval_final[(eval_final["pathological"] == True)]) #& (report_final["Normal"] == True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cb15bdf1cf67> in <module>
# ----> 1 len(eval_final[(eval_final["pathological"] == True)]) #& (report_final["Normal"] == True)
#
# NameError: name 'eval_final' is not defined

# %%
len(eval_final[(eval_final["pathological"] == True)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-66ea3ba92b90> in <module>
# ----> 1 len(eval_final[(eval_final["pathological"] == True)])
#
# NameError: name 'eval_final' is not defined

# %%
len(eval_final[(eval_final["pathological"] == False)])

# %%
len(eval_final[(eval_final["Normal"] == True)])

# %%
27244/34894

# %%
27244/7650

# %%
train_combined=tuh_selected

# %%
train_combined= pd.read_pickle("./selected_labelled_reports_15min.pkl")

# %%
df_sorted= train_combined.sort_values(by=['year', 'month', 'day', 'subject', 'session', 'segment'])
# ids_sorted = list(df_sorted.index)
# train_complete = train_combined.split(ids_sorted)['0']

#df_sorted['pathological']= df_sorted['PATHOLOGICAL'].astype(int)

#df_sorted= df_sorted.drop(columns=['PATHOLOGICAL', 'Normal'])

# %%
df_sorted
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     10
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# ...                                                  ...     ...   ...    ...
# 15295  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      1
# 15296  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15297  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15298  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 15299  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
#
#        day  subject  session  segment reference   sfreq  n_samples  age  \
# 0        4       14        1        1        le   250.0     306500   57
# 1       19        5        1        1        le   250.0     357000   49
# 2       21        6        1        2        le   250.0     354000   31
# 3       23       11        1        0        le   250.0     304000   31
# 4       24        7        1        0        le   250.0     300000   40
# ...    ...      ...      ...      ...       ...     ...        ...  ...
# 15295   23    14101        1        0        ar  1000.0    1420000   75
# 15296    3    13738        1        0        ar   256.0     340992   65
# 15297    8    11124        3        1        ar   256.0     383488   26
# 15298   15    11954        3        1        ar   256.0    9140992   54
# 15299   15    11954        3        2        ar   256.0    1812480   54
#
#       gender                                             report  \
# 0          M  CLINICAL HISTORY: This is a 57-year-old, right...
# 1          M  \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 2          F  \n\n\n\n\n\n\n\n\nCLINICAL  HISTORY:  This  is...
# 3          F  CLINICAL HISTORY: This is a 31-year-old woman ...
# 4          M  CLINICAL HISTORY: This is a 42-year-old man wi...
# ...      ...                                                ...
# 15295      F  DATE OF STUDY: 01/23/17
# RECORDING ENVIRONMENT:...
# 15296      M  HISTORY:\n\n64 y.o. male with a history of gun...
# 15297      M  HISTORY:\n\n25 y.o. male with a history of idi...
# 15298      F  HISTORY:\n\n53 y.o. female with a history of m...
# 15299      F  HISTORY:\n\n53 y.o. female with a history of m...
#
#                                               impression  pathological dataset
# 0      impression: probably abnormal eeg due to right...             1  TUHEEG
# 1      impression: abnormal eeg due to 1. right tempo...             1  TUHEEG
# 2      impression: abnormal long-term video eeg monit...             1  TUHEEG
# 3      impression: normal eeg in wakefulness through ...             0  TUHEEG
# 4      impression: abnormal eeg due to focal slowing ...             1  TUHEEG
# ...                                                  ...           ...     ...
# 15295  impression:
# this is an abnormal bedside eeg du...             1  TUHEEG
# 15296  impression \n\n\nthis is an abnormal awake and...             1  TUHEEG
# 15297  impression \nthis is an abnormal awake only  r...             1  TUHEEG
# 15298  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
# 15299  impression \n\n\n\nthis is an abnormal awake a...             1  TUHEEG
#
# [15300 rows x 17 columns]

# %%
df_sorted2=df_sorted.reset_index(drop=True)

# %%
#spilt in eval and train set SKF 10fold last fold

# %%
from sklearn.model_selection import StratifiedKFold 
skf = StratifiedKFold(n_splits=10,shuffle=False) 
target=df_sorted2.loc[:,'pathological']

# %%
df=df_sorted2
fold_no = 1
for train_index, test_index in skf.split(df, target):
    train = df.loc[train_index,:]
    test = df.loc[test_index,:]
    print('Fold',str(fold_no),'Class Ratio:',sum(test['pathological'])/len(test['pathological']))
    fold_no += 1
# Out:
# Fold 1 Class Ratio: 0.7084967320261438
# Fold 2 Class Ratio: 0.7084967320261438
# Fold 3 Class Ratio: 0.7084967320261438
# Fold 4 Class Ratio: 0.7084967320261438
# Fold 5 Class Ratio: 0.7084967320261438
# Fold 6 Class Ratio: 0.7084967320261438
# Fold 7 Class Ratio: 0.7084967320261438
# Fold 8 Class Ratio: 0.7084967320261438
# Fold 9 Class Ratio: 0.707843137254902
# Fold 10 Class Ratio: 0.707843137254902

# %%
train['train']= True
train
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     10
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# ...                                                  ...     ...   ...    ...
# 13849  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13850  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13851  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13852  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13853  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        4       14        1        1        le  250.0     306500   57      M
# 1       19        5        1        1        le  250.0     357000   49      M
# 2       21        6        1        2        le  250.0     354000   31      F
# 3       23       11        1        0        le  250.0     304000   31      F
# 4       24        7        1        0        le  250.0     300000   40      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 13849   25    14090        4        0        ar  256.0    5581312   41      F
# 13850   25    14090        4        1        ar  256.0    5477888   41      F
# 13851   25    14090        5        0        ar  256.0   11059200   41      F
# 13852   25    14090        6        0        ar  256.0    4936448   41      F
# 13853   25    14090        6        2        ar  256.0    4830976   41      F
#
#                                                   report  \
# 0      CLINICAL HISTORY: This is a 57-year-old, right...
# 1      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 2      \n\n\n\n\n\n\n\n\nCLINICAL  HISTORY:  This  is...
# 3      CLINICAL HISTORY: This is a 31-year-old woman ...
# 4      CLINICAL HISTORY: This is a 42-year-old man wi...
# ...                                                  ...
# 13849  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13850  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13851  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13852  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13853  HISTORY:\n\nThis is a 41 y.o. right handed fem...
#
#                                               impression  pathological  \
# 0      impression: probably abnormal eeg due to right...             1
# 1      impression: abnormal eeg due to 1. right tempo...             1
# 2      impression: abnormal long-term video eeg monit...             1
# 3      impression: normal eeg in wakefulness through ...             0
# 4      impression: abnormal eeg due to focal slowing ...             1
# ...                                                  ...           ...
# 13849  impression & clinical correlation \nthis is a ...             0
# 13850  impression & clinical correlation \nthis is a ...             0
# 13851  impression & clinical correlation \nthis is a ...             0
# 13852  impression & clinical correlation \nthis is a ...             0
# 13853  impression & clinical correlation \nthis is a ...             0
#
#       dataset  train
# 0      TUHEEG   True
# 1      TUHEEG   True
# 2      TUHEEG   True
# 3      TUHEEG   True
# 4      TUHEEG   True
# ...       ...    ...
# 13849  TUHEEG   True
# 13850  TUHEEG   True
# 13851  TUHEEG   True
# 13852  TUHEEG   True
# 13853  TUHEEG   True
#
# [13770 rows x 18 columns]

# %%
test['train']= False
test
# Out:
#                                                     path version  year  month  \
# 25963  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 25964  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 25965  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 25966  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 25967  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# ...                                                  ...     ...   ...    ...
# 29057  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 29058  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      2
# 29059  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 29060  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
# 29061  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2017      3
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 25963   19    14208        2        1        ar  256.0    6004992   53      M
# 25964   19    14208        3        0        ar  256.0    9712896   53      M
# 25965   19    14252        3        0        ar  256.0     376320   34      M
# 25966   19    14404        1        1        ar  250.0     326000   56      F
# 25967   19    14438        1        0        ar  512.0     652288   64      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 29057   15    11954        3        1        ar  256.0    9140992   54      F
# 29058   15    11954        3        2        ar  256.0    1812480   54      F
# 29059    3    14898        1        2        ar  256.0     126976   26      F
# 29060    3    14898        1        3        ar  256.0     173056   26      F
# 29061    3    14898        1        4        ar  256.0     107520   26      F
#
#                                                   report  \
# 25963  HISTORY:\n\n\n52 y.o. male with a history of h...
# 25964  HISTORY:\n\n52 y.o. male with a history of hea...
# 25965  HISTORY:\n\n33 y.o. MAN PRESENTS WITH H/O PRIO...
# 25966  HISTORY:\n\n55 y.o. female with a history of h...
# 25967  HISTORY:\n\n63 y.o. male with a history of mem...
# ...                                                  ...
# 29057  HISTORY:\n\n53 y.o. female with a history of m...
# 29058  HISTORY:\n\n53 y.o. female with a history of m...
# 29059  HISTORY:\n\n25 y.o. female with a history of f...
# 29060  HISTORY:\n\n25 y.o. female with a history of f...
# 29061  HISTORY:\n\n25 y.o. female with a history of f...
#
#                                               impression  pathological  \
# 25963  impression & clinical correlation \n\nthis is ...             1
# 25964  impression & clinical correlation \n\nthis is ...             1
# 25965  impression \nthis is an abnormal awake and asl...             1
# 25966  impression \nthis is an abnormal coma study po...             1
# 25967  impression \n\nthis is an abnormal awake and d...             1
# ...                                                  ...           ...
# 29057  impression \n\n\n\nthis is an abnormal awake a...             1
# 29058  impression \n\n\n\nthis is an abnormal awake a...             1
# 29059  impression \n\nthis is a normal awake and drow...             0
# 29060  impression \n\nthis is a normal awake and drow...             0
# 29061  impression \n\nthis is a normal awake and drow...             0
#
#       dataset  train
# 25963  TUHEEG  False
# 25964  TUHEEG  False
# 25965  TUHEEG  False
# 25966  TUHEEG  False
# 25967  TUHEEG  False
# ...       ...    ...
# 29057  TUHEEG  False
# 29058  TUHEEG  False
# 29059  TUHEEG  False
# 29060  TUHEEG  False
# 29061  TUHEEG  False
#
# [2906 rows x 18 columns]

# %%
final = pd.concat([train, test]).reset_index(drop=True)

# %%
final_train= train.reset_index(drop=True)
final_eval=test.reset_index(drop=True)

# %%
final.to_pickle('/home/kiessnek/TUHEEG_decoding/labels/final_tuabex_description.pkl')
final_train.to_pickle('/home/kiessnek/TUHEEG_decoding/labels/final_train_tuabex_description.pkl')
final_eval.to_pickle('/home/kiessnek/TUHEEG_decoding/labels/final_eval_tuabex_description.pkl')

# %%
final.to_pickle('./final_tuabex_description.pkl')
final_train.to_pickle('./final_train_tuabex_description.pkl')
final_eval.to_pickle('./final_eval_tuabex_description.pkl')

# %%
import time
#from combineTUHdatasets import *
print('load data ' )
start_load = time.time()
recording_ids=None
with io.capture_output() as captured:
    dataset_train, TUH_label_list = get_TUH_labeled(path_TUH='/data/datasets/TUH/EEG/tuh_eeg/', 
                                                                     label_file= '/home/kiessnek/TUHEEG_decoding/labels/final_train_tuabex_description.pkl', 
                                                                     recording_ids=None) #CombineTUHDatasets.
end_load= time.time()
print(end_load -start_load)

# load data 
# 1321.5568685531616
# Out:
# load data
# 1284.9824883937836

# %%
df_sorted= dataset_train.description.sort_values(by=['year', 'month', 'day', 'subject','session','segment'])
ids_sorted = list(df_sorted.index)
train_complete = dataset_train.split(ids_sorted)['0']

# %%
train_complete.description
# Out:
#                                                     path version  year  month  \
# 0      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     10
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 4      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# ...                                                  ...     ...   ...    ...
# 13765  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13766  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13767  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13768  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13769  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0        4       14        1        1        le  250.0     306500   57      M
# 1       19        5        1        1        le  250.0     357000   49      M
# 2       21        6        1        2        le  250.0     354000   31      F
# 3       23       11        1        0        le  250.0     304000   31      F
# 4       24        7        1        0        le  250.0     300000   40      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 13765   25    14090        4        0        ar  256.0    5581312   41      F
# 13766   25    14090        4        1        ar  256.0    5477888   41      F
# 13767   25    14090        5        0        ar  256.0   11059200   41      F
# 13768   25    14090        6        0        ar  256.0    4936448   41      F
# 13769   25    14090        6        2        ar  256.0    4830976   41      F
#
#                                                   report  \
# 0      CLINICAL HISTORY: This is a 57-year-old, right...
# 1      \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 2      \n\n\n\n\n\n\n\n\nCLINICAL  HISTORY:  This  is...
# 3      CLINICAL HISTORY: This is a 31-year-old woman ...
# 4      CLINICAL HISTORY: This is a 42-year-old man wi...
# ...                                                  ...
# 13765  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13766  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13767  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13768  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13769  HISTORY:\n\nThis is a 41 y.o. right handed fem...
#
#                                               impression  pathological  \
# 0      impression: probably abnormal eeg due to right...             1
# 1      impression: abnormal eeg due to 1. right tempo...             1
# 2      impression: abnormal long-term video eeg monit...             1
# 3      impression: normal eeg in wakefulness through ...             0
# 4      impression: abnormal eeg due to focal slowing ...             1
# ...                                                  ...           ...
# 13765  impression & clinical correlation \nthis is a ...             0
# 13766  impression & clinical correlation \nthis is a ...             0
# 13767  impression & clinical correlation \nthis is a ...             0
# 13768  impression & clinical correlation \nthis is a ...             0
# 13769  impression & clinical correlation \nthis is a ...             0
#
#       dataset  train
# 0      TUHEEG   True
# 1      TUHEEG   True
# 2      TUHEEG   True
# 3      TUHEEG   True
# 4      TUHEEG   True
# ...       ...    ...
# 13765  TUHEEG   True
# 13766  TUHEEG   True
# 13767  TUHEEG   True
# 13768  TUHEEG   True
# 13769  TUHEEG   True
#
# [13770 rows x 18 columns]

# %%
tuh = dataset_train
tuh_splits = tuh.split([[i] for i in range(len(dataset_train.datasets))])
#tuh_splits2 =  dict(list(tuh_splits.items())[23000:])

duration = []


for ds, tuh_subset in tqdm(tuh_splits.items()):
    duration.append (tuh_subset.description.n_samples / tuh_subset.description.sfreq)

duration_train = train_complete.description
duration_train['duration']=list(duration)

duration_train.to_pickle('./duration_train_tuabextended.pkl')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=13770.0), HTML(value='')))

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import mne

from braindecode.datasets import TUH
from braindecode.datautil.preprocess import preprocess, Preprocessor
from braindecode.datautil.windowers import create_fixed_length_windows
from braindecode.preprocessing import (
    preprocess, Preprocessor, create_fixed_length_windows, scale as multiply)

mne.set_log_level('ERROR')  # avoid messages everytime a window is extracted

# %%
short_ch_names = sorted([
                'A1', 'A2', 'C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8',
                'Fp1', 'Fp2', 'Fz', 'O1', 'O2', 'P3', 'P4', 'Pz', 'T3',
                 'T4', 'T5', 'T6'
            ])
ar_ch_names = sorted([
    'EEG A1-REF', 'EEG A2-REF',
    'EEG FP1-REF', 'EEG FP2-REF', 'EEG F3-REF', 'EEG F4-REF', 'EEG C3-REF',
    'EEG C4-REF', 'EEG P3-REF', 'EEG P4-REF', 'EEG O1-REF', 'EEG O2-REF',
    'EEG F7-REF', 'EEG F8-REF', 'EEG T3-REF', 'EEG T4-REF', 'EEG T5-REF',
    'EEG T6-REF', 'EEG FZ-REF', 'EEG CZ-REF', 'EEG PZ-REF'])
le_ch_names = sorted([
    'EEG A1-LE', 'EEG A2-LE',
    'EEG FP1-LE', 'EEG FP2-LE', 'EEG F3-LE', 'EEG F4-LE', 'EEG C3-LE',
    'EEG C4-LE', 'EEG P3-LE', 'EEG P4-LE', 'EEG O1-LE', 'EEG O2-LE',
    'EEG F7-LE', 'EEG F8-LE', 'EEG T3-LE', 'EEG T4-LE', 'EEG T5-LE',
    'EEG T6-LE', 'EEG FZ-LE', 'EEG CZ-LE', 'EEG PZ-LE'])
assert len(short_ch_names) == len(ar_ch_names) == len(le_ch_names)
ar_ch_mapping = {ch_name: short_ch_name for ch_name, short_ch_name in zip(
    ar_ch_names, short_ch_names)}
le_ch_mapping = {ch_name: short_ch_name for ch_name, short_ch_name in zip(
    le_ch_names, short_ch_names)}
ch_mapping = {'ar': ar_ch_mapping, 'le': le_ch_mapping}



def custom_rename_channels(raw, mapping):
    # rename channels which are dependent on referencing:
    # le: EEG 01-LE, ar: EEG 01-REF
    # mne fails if the mapping contains channels as keys that are not present
    # in the raw
    reference = raw.ch_names[0].split('-')[-1].lower()
    assert reference in ['le', 'ref'], 'unexpected referencing'
    reference = 'le' if reference == 'le' else 'ar'
    raw.rename_channels(mapping[reference])


def custom_crop(raw, tmin=0.0, tmax=None, include_tmax=True):
    # crop recordings to tmin – tmax. can be incomplete if recording
    # has lower duration than tmax
    # by default mne fails if tmax is bigger than duration
    tmax = min((raw.n_times - 1) / raw.info['sfreq'], tmax)
    raw.crop(tmin=tmin, tmax=tmax, include_tmax=include_tmax)


n_max_minutes=21
tmin = 1 * 60
tmax = n_max_minutes * 60
sfreq = 100

preprocessors = [
    Preprocessor(custom_crop, tmin=tmin, tmax=tmax, include_tmax=False,
                 apply_on_array=False),

    Preprocessor(custom_rename_channels, mapping=ch_mapping,
                 apply_on_array=False),
    Preprocessor('pick_channels', ch_names=short_ch_names, ordered=True),
 
    Preprocessor(multiply, factor=1e6, apply_on_array=True),
    Preprocessor(np.clip, a_min=-800, a_max=800, apply_on_array=True),
    
    Preprocessor('set_eeg_reference', ref_channels='average', ch_type='eeg'),

    Preprocessor('resample', sfreq=sfreq),
    Preprocessor('set_meas_date', meas_date=None)
    
]

# %%
target = train_complete.description['pathological']



for d, y in zip(train_complete.datasets, target):
    d.description['pathological'] = y
    d.target_name = 'pathological'
    d.target = d.description[d.target_name]
train_complete.set_description(pd.DataFrame([d.description for d in train_complete.datasets]), overwrite=True)

# %%
preprocess(
            concat_ds=train_complete,
            preprocessors=preprocessors,
            n_jobs=4,  # will be available with PR277
            save_dir='/home/kiessnek/data/preprocessed_TUABExtended/final_train/',  # will be available with PR277
        )

# %%
train_complete.description.to_pickle('./TUABEX_trainset.pkl')

# %%
print('load data ' )
start_load = time.time()
recording_ids=None
with io.capture_output() as captured:
    dataset_eval, TUH_label_list = get_TUH_labeled(path_TUH='/data/datasets/TUH/EEG/tuh_eeg/', 
                                                                     label_file= '/home/kiessnek/TUHEEG_decoding/labels/final_eval_tuabex_description.pkl', 
                                                                     recording_ids=None) #CombineTUHDatasets.
end_load= time.time()
print(end_load -start_load)
# Out:
# load data
# 151.72280645370483

# %%
eval_complete=dataset_eval

# %%
df_sorted= dataset_eval.description.sort_values(by=['year', 'month', 'day', 'subject','session','segment'])
ids_sorted = list(df_sorted.index)
eval_complete = dataset_eval.split(ids_sorted)['0']


target = eval_complete.description['pathological']



for d, y in zip(eval_complete.datasets, target):
    d.description['pathological'] = y
    d.target_name = 'pathological'
    d.target = d.description[d.target_name]
eval_complete.set_description(pd.DataFrame([d.description for d in eval_complete.datasets]), overwrite=True)

# %%
tuh = eval_complete
tuh_splits = tuh.split([[i] for i in range(len(eval_complete.datasets))])
#tuh_splits2 =  dict(list(tuh_splits.items())[23000:])

duration = []


for ds, tuh_subset in tqdm(tuh_splits.items()):
    duration.append (tuh_subset.description.n_samples / tuh_subset.description.sfreq)

duration_eval = eval_complete.description
duration_eval['duration']=list(duration)

duration_eval.to_pickle('./duration_eval_tuabextended.pkl')
#del dataset_eval
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1530.0), HTML(value='')))

# %%
preprocess(
            concat_ds=eval_complete,
            preprocessors=preprocessors,
            n_jobs=4,  # will be available with PR277
            save_dir='/home/kiessnek/data/preprocessed_TUABExtended/final_eval/',  # will be available with PR277
        )

# %%
eval_complete.description.to_pickle('./TUABEX_evalset.pkl')

# %%
len(train_complete), len(eval_complete)

# %%
len(final_train), len(final_eval)
# Out:
# (13770, 1530)

# %%
final_eval = eval_complete.description
final_train=train_complete.description

# %%
len(final_eval[final_eval['pathological']==1]), len(final_eval[final_eval['pathological']==0])
# Out:
# (1083, 447)

# %%
len(final_train[final_train['pathological']==1]), len(final_train[final_train['pathological']==0])
# Out:
# (9755, 4015)

# %%
9755/3
# Out:
# 3251.6666666666665

# %%
2177/3
# Out:
# 725.6666666666666

# %%
6174+5729, 6174/11903

# %%
18522-4630, 5729-4630, 1099/13892

# %%
100/14

# %%
#final.to_pickle('./final_tuabex_description.pkl')
final_train=pd.read_pickle('./final_train_tuabex_description.pkl')
final_eval=pd.read_pickle('./final_eval_tuabex_description.pkl')

# %%
final_train=pd.read_pickle('./TUABEX_trainset.pkl')
final_eval=pd.read_pickle('./TUABEX_evalset.pkl')

# %%
len(final_train[final_train['pathological']==1]),len(final_train[final_train['pathological']==0])
# Out:
# (9755, 4015)

# %%
final_train[final_train['pathological']==0]
# Out:
#                                                     path version  year  month  \
# 3      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 8      /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 18     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      1
# 21     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      1
# 24     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      1
# ...                                                  ...     ...   ...    ...
# 13765  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13766  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13767  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13768  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 13769  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
#
#        day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 3       23       11        1        0        le  250.0     304000   31      F
# 8       26        8        1        1        le  250.0     287750   18      F
# 18       8      261        1        1        le  250.0     338750   79      F
# 21       8      325        1        1        le  250.0     343750   37      M
# 24       9      290        2        8        le  250.0    1348000   54      M
# ...    ...      ...      ...      ...       ...    ...        ...  ...    ...
# 13765   25    14090        4        0        ar  256.0    5581312   41      F
# 13766   25    14090        4        1        ar  256.0    5477888   41      F
# 13767   25    14090        5        0        ar  256.0   11059200   41      F
# 13768   25    14090        6        0        ar  256.0    4936448   41      F
# 13769   25    14090        6        2        ar  256.0    4830976   41      F
#
#                                                   report  \
# 3      CLINICAL HISTORY: This is a 31-year-old woman ...
# 8      CLINICAL HISTORY: This is a 19-year-old female...
# 18     CLINICAL HISTORY: This is a 78-year-old, right...
# 21     CLINICAL HISTORY: This is a 39-year-old, right...
# 24     CLINICAL HISTORY: This is a 53-year-old gentle...
# ...                                                  ...
# 13765  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13766  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13767  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13768  HISTORY:\n\nThis is a 41 y.o. right handed fem...
# 13769  HISTORY:\n\nThis is a 41 y.o. right handed fem...
#
#                                               impression  pathological  \
# 3      impression: normal eeg in wakefulness through ...             0
# 8      impression: eeg within normal limits in wakefu...             0
# 18       impression:  eeg within normal limits for age.              0
# 21     impression: normal eeg in wakefulness and brie...             0
# 24     impression: normal eeg in wakefulness through ...             0
# ...                                                  ...           ...
# 13765  impression & clinical correlation \nthis is a ...             0
# 13766  impression & clinical correlation \nthis is a ...             0
# 13767  impression & clinical correlation \nthis is a ...             0
# 13768  impression & clinical correlation \nthis is a ...             0
# 13769  impression & clinical correlation \nthis is a ...             0
#
#       dataset  train
# 3      TUHEEG   True
# 8      TUHEEG   True
# 18     TUHEEG   True
# 21     TUHEEG   True
# 24     TUHEEG   True
# ...       ...    ...
# 13765  TUHEEG   True
# 13766  TUHEEG   True
# 13767  TUHEEG   True
# 13768  TUHEEG   True
# 13769  TUHEEG   True
#
# [4015 rows x 18 columns]

# %%
len(final_eval[final_eval['pathological']==1]),len(final_eval[final_eval['pathological']==0])
# Out:
# (1083, 447)

# %%
len(final_train), len(final_eval)
# Out:
# (13770, 1530)

# %%
train_set= final_train
eval_set=final_eval

train_set['index']=train_set.index


eval_set['index']=eval_set.index

train_set_normal = train_set[train_set['pathological']==0]
train_set_patho = train_set[train_set['pathological']==1].reset_index(drop=True)

eval_set_normal = eval_set[eval_set['pathological']==0]
eval_set_patho = eval_set[eval_set['pathological']==1].reset_index(drop=True)

train_normal = train_set[(train_set['pathological'] == 0)]
train_patho = train_set[(train_set['pathological'] == 1)]
train_patho = train_patho.reset_index(drop=True)

# %%
import pickle
with open("/home/kiessnek/TUHEEG_decoding/indices/indices_TUABEX_patho_train_set.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(train_set_patho['index']), fp) 
    
with open("/home/kiessnek/TUHEEG_decoding/indices/indices_TUABEX_patho_eval_set.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(eval_set_patho['index']), fp)

# %%
with open("/home/kiessnek/TUHEEG_decoding/indices/indices_TUABEX_normal_train_set.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(train_set_normal['index']), fp) 
    
with open("/home/kiessnek/TUHEEG_decoding/indices/indices_TUABEX_normal_eval_set.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(eval_set_normal['index']), fp)

# %%
train_patho
# Out:
#                                                    path version  year  month  \
# 0     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 2     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     10
# 3     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 4     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# ...                                                 ...     ...   ...    ...
# 9750  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9751  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9752  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9753  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9754  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
#
#       day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0       4       14        1        1        le  250.0     306500   57      M
# 1      19        5        1        1        le  250.0     357000   49      M
# 2      21        6        1        2        le  250.0     354000   31      F
# 3      24        7        1        0        le  250.0     300000   40      M
# 4      24       12        1        0        le  250.0     270750   58      F
# ...   ...      ...      ...      ...       ...    ...        ...  ...    ...
# 9750    1    14583       14       13        ar  256.0    1609728   20      F
# 9751    1    14583       15        0        ar  256.0     784896   20      F
# 9752    1    14583       15        1        ar  256.0    1402624   20      F
# 9753    1    14583       15        2        ar  256.0     562944   20      F
# 9754    1    14583       15        3        ar  256.0    1322752   20      F
#
#                                                  report  \
# 0     CLINICAL HISTORY: This is a 57-year-old, right...
# 1     \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 2     \n\n\n\n\n\n\n\n\nCLINICAL  HISTORY:  This  is...
# 3     CLINICAL HISTORY: This is a 42-year-old man wi...
# 4     CLINICAL HISTORY: This is a 58-year-old woman ...
# ...                                                 ...
# 9750  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9751  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9752  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9753  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9754  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
#
#                                              impression  pathological dataset  \
# 0     impression: probably abnormal eeg due to right...             1  TUHEEG
# 1     impression: abnormal eeg due to 1. right tempo...             1  TUHEEG
# 2     impression: abnormal long-term video eeg monit...             1  TUHEEG
# 3     impression: abnormal eeg due to focal slowing ...             1  TUHEEG
# 4     impression: abnormal eeg due to generalized ba...             1  TUHEEG
# ...                                                 ...           ...     ...
# 9750  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9751  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9752  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9753  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9754  impression & clinical correlation:
# this is an ...             1  TUHEEG
#
#       train  index
# 0      True      0
# 1      True      1
# 2      True      2
# 3      True      4
# 4      True      5
# ...     ...    ...
# 9750   True  13695
# 9751   True  13696
# 9752   True  13697
# 9753   True  13698
# 9754   True  13699
#
# [9755 rows x 19 columns]

# %%
r = np.arange(len(train_patho))

r_eval =np.arange(len(eval_set_patho))

# %%
pidx_eval =r_eval[0:len(eval_set_patho):3]
pidx_train= r[0:len(train_patho):3]

# %%
len(pidx_eval), len(pidx_train)
# Out:
# (361, 3252)

# %%
list1= list(train_patho.index)
list2=list(pidx_train)
rest_train_patho= [item for item in list1 if item not in list2]



len(rest_train_patho)

r = np.arange(len(train_patho))
pidx_train2= r[0:len(rest_train_patho):9]

len(pidx_train2)
# Out:
# 723

# %%
list1= list(eval_set_patho.index)
list2=list(pidx_eval)
rest_eval_patho= [item for item in list1 if item not in list2]



len(rest_eval_patho)

r = np.arange(len(eval_set_patho))
pidx_eval2= r[0:len(rest_eval_patho):9]

len(pidx_eval2)
# Out:
# 81

# %%
#jedes 3te und dann vom rest jedes 9te damit fast gleich mit normal recs

# %%
train_patho_bal= train_patho.loc[sorted(list(pidx_train)+list(np.array(rest_train_patho)[pidx_train2]))]

eval_patho_bal= eval_set_patho.loc[sorted(list(pidx_eval)+list(np.array(rest_eval_patho)[pidx_eval2]))]

# %%
len(eval_patho_bal),len(eval_set_normal)  # jedes 9
# Out:
# (442, 447)

# %%
len(train_patho_bal),len(train_set_normal)  # jedes 9
# Out:
# (3975, 4015)

# %%
3975+4015
# Out:
# 7990

# %%
3975/(3975+4015), 442/(442+447)
# Out:
# (0.4974968710888611, 0.49718785151856015)

# %%
126/(126+150)
# Out:
# 0.45652173913043476

# %%
6885-6130,24520-6130,755/18390
# Out:
# (755, 18390, 0.04105492115280043)

# %%
train_patho_bal[train_patho_bal['pathological']==1]
# Out:
#                                                    path version  year  month  \
# 0     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 1     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002      9
# 3     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 6     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2002     12
# 9     /data/datasets/TUH/EEG/tuh_eeg/v1.1.0/edf/02_t...  v1.1.0  2003      1
# ...                                                 ...     ...   ...    ...
# 9744  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9747  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9748  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9750  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
# 9753  /data/datasets/TUH/EEG/tuh_eeg/v1.2.0/edf/01_t...  v1.2.0  2016      7
#
#       day  subject  session  segment reference  sfreq  n_samples  age gender  \
# 0       4       14        1        1        le  250.0     306500   57      M
# 1      19        5        1        1        le  250.0     357000   49      M
# 3      24        7        1        0        le  250.0     300000   40      M
# 6      26        2        3        0        le  250.0     307250   55      F
# 9       7        2        6        1        le  250.0     303000   56      F
# ...   ...      ...      ...      ...       ...    ...        ...  ...    ...
# 9744    1    14583       14        6        ar  256.0    3480576   20      F
# 9747    1    14583       14       10        ar  256.0     869376   20      F
# 9748    1    14583       14       11        ar  256.0     925696   20      F
# 9750    1    14583       14       13        ar  256.0    1609728   20      F
# 9753    1    14583       15        2        ar  256.0     562944   20      F
#
#                                                  report  \
# 0     CLINICAL HISTORY: This is a 57-year-old, right...
# 1     \n\nCLINICAL HISTORY: 49-year-old male with a ...
# 3     CLINICAL HISTORY: This is a 42-year-old man wi...
# 6     CLINICAL HISTORY: This is a 55-year-old, right...
# 9     CLINICAL HISTORY: This is a 55-year-old woman ...
# ...                                                 ...
# 9744  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9747  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9748  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9750  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
# 9753  HISTORY:
# 20 y.o. woman transfer from Jeanes du...
#
#                                              impression  pathological dataset  \
# 0     impression: probably abnormal eeg due to right...             1  TUHEEG
# 1     impression: abnormal eeg due to 1. right tempo...             1  TUHEEG
# 3     impression: abnormal eeg due to focal slowing ...             1  TUHEEG
# 6     impression: abnormal eeg due to replacement of...             1  TUHEEG
# 9     impression: abnormal eeg due to excess beta an...             1  TUHEEG
# ...                                                 ...           ...     ...
# 9744  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9747  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9748  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9750  impression & clinical correlation:
# this is an ...             1  TUHEEG
# 9753  impression & clinical correlation:
# this is an ...             1  TUHEEG
#
#       train  index
# 0      True      0
# 1      True      1
# 3      True      4
# 6      True      7
# 9      True     11
# ...     ...    ...
# 9744   True  13689
# 9747   True  13692
# 9748   True  13693
# 9750   True  13695
# 9753   True  13698
#
# [3975 rows x 19 columns]

# %%
ind_bal_train = list(sorted(list(train_patho_bal['index'])+ list(train_set_normal['index'])))

trainbal = final_train.iloc[ind_bal_train]

len(trainbal[trainbal['pathological']==0]),len(trainbal[trainbal['pathological']==1])
# Out:
# (4015, 3975)

# %%
trainbal[trainbal['pathological']==0]['index']
# Out:
# 3            3
# 8            8
# 18          18
# 21          21
# 24          24
#          ...
# 13765    13765
# 13766    13766
# 13767    13767
# 13768    13768
# 13769    13769
# Name: index, Length: 4015, dtype: int64

# %%
ind_bal_eval = list(sorted(list(eval_patho_bal['index'])+ list(eval_set_normal['index'])))

evalbal = final_eval.iloc[ind_bal_eval]

len(evalbal[evalbal['pathological']==0]),len(evalbal[evalbal['pathological']==1])
# Out:
# (447, 442)

# %%
import pickle
with open("/home/kiessnek/TUHEEG_decoding/indices/saturation/indices_TUABEx_balanced_train_patho.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(trainbal[trainbal['pathological']==1]['index']), fp)
    
with open("/home/kiessnek/TUHEEG_decoding/indices/saturation/indices_TUABEx_balanced_train_normal.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(trainbal[trainbal['pathological']==0]['index']), fp)    
    
with open("/home/kiessnek/TUHEEG_decoding/indices/saturation/indices_TUABEx_balanced_eval_patho.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(evalbal[evalbal['pathological']==1]['index']), fp)
    
with open("/home/kiessnek/TUHEEG_decoding/indices/saturation/indices_TUABEx_balanced_eval_normal.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(evalbal[evalbal['pathological']==0]['index']), fp)

# %%
with open("/home/kiessnek/TUHEEG_decoding/indices/saturation/indices_TUABEx_balanced_train_set.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(trainbal['index']), fp)

# %%
with open("/home/kiessnek/TUHEEG_decoding/indices/saturation/indices_TUABEx_balanced_eval_set.pkl", "wb") as fp:   #Pickling
    pickle.dump(list(evalbal['index']), fp)

# %%
trainbal.to_pickle('./TUABEX_train_set_balanced.pkl')

# %%
evalbal.to_pickle('./TUABEX_eval_set_balanced.pkl')

# %%
## get indidces for saturation combined

# %%
train_tuab= pd.read_pickle("/home/kiessnek/TUHEEG_decoding/labels/TUHABnormaldescription_train.pkl")

# %%
train_tuab['index']=train_tuab.index

# %%
train_tuab['dataset']='TUHAB'

# %%
combi_train= pd.concat([trainbal,train_tuab])
combi_train= combi_train.sort_values(by=['year', 'month', 'day', 'subject', 'session', 'segment'])

# %%
combi_train_patho = combi_train[combi_train['pathological']==1].reset_index(drop=True)
combi_train_normal = combi_train[combi_train['pathological']==0].reset_index(drop=True)

# %%
idx=4800

# %%
combi_train_patho.iloc[0:idx][combi_train_patho.iloc[0:idx]['dataset']=='TUHAB']

# %%
combi_train_normal.iloc[0:idx][combi_train_normal.iloc[0:idx]['dataset']=='TUHAB']

# %%
combi_train_normal

# %%
abnormal_reports = reports[reports['PATHOLOGICAL'] == True]
normal_reports = reports[reports['Normal'] == True]
nan_reports = reports[reports['PATHOLOGICAL'] == 'nan']
no_normal= reports[reports['Normal'] == 'no label']

# %%
# from braindecode.datasets.tuh import TUHAbnormal
# data_path = '/data/schirrmr/gemeinl/tuh-abnormal-eeg/raw/'#'/data/schirrmr/gemeinl/tuh-abnormal-eeg/raw/'
# dataset = TUHAbnormal(
#     path=data_path,
#     recording_ids=None, #range(len(rec_id)),  # loads the n chronologically first recordings # range(n_recordings_to_load)
#     target_name= 'pathological',#target_name,  # age, gender, pathology

#     add_physician_reports=True,  # Comment Lukas uncomment to also read physician reports
# )
# tuab =dataset.description

# tuab.to_pickle("/home/kiessnek/TUHEEG_decoding/labels/TUHABnormaldescription.pkl")

# %%
final_train = pd.read_pickle("/home/kiessnek/TUHEEG_decoding/labels/final_train.pkl") 
final_eval = pd.read_pickle("/home/kiessnek/TUHEEG_decoding/labels/eval_final_set_sep.pkl") 

final_train['train'] = True
final_eval['train'] =False

final = pd.concat([final_train, final_eval])
reports =final.reset_index(drop=True)

# %%
final_tueg = reports.drop(columns=['pathological_label', 'PATHOLOGICAL', 'Normal'])

# %%
final_tueg.to_pickle('/home/kiessnek/TUHEEG_decoding/labels/final_tueg_description.pkl')
final_tueg.to_csv('/home/kiessnek/TUHEEG_decoding/labels/final_tueg_description.csv')
